# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.9 MB/s eta 0:00:00

# %%
data_yaml = "/content/drive/MyDrive/1:1_Srikrishna_Kataru/Pinworm_Detection_Egg_Detection/Dataset/Pinworm-Egg-Detection-1/data.yaml"

# %%
# define the number of epochs and learning rate

! yolo task=detect mode=train model=yolov8s.pt data={data_yaml} optimizer="Adam" epochs=15 imgsz=640 lr0=0.001 name=yolov8n_custom
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# Save the model

# %%
# Specify the directory path you want to check/create
import os
import shutil

# define the best model name
model_name = f'yolov8_best_model_epoch_15_lr_0.001'
model_folder = '/content/drive/MyDrive/1:1_Srikrishna_Kataru/Pinworm_Detection_Egg_Detection/Models'
destination_path = os.path.join(model_folder, model_name)

# define the best model custom data path
source_path = '/content/runs/detect/yolov8n_custom'
shutil.move(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/1:1_Srikrishna_Kataru/Pinworm_Detection_Egg_Detection/Models/yolov8_best_model_epoch_15_lr_0.001'
